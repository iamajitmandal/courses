# %%
#open the file
file =open("sample.txt","r")

#read the content
content=file.read()
print(content)

#close the file
file.close()
# Out:
# welcome to the first class of file handling

# %%
file=open("demo.txt","w")
file.write("Hello World!\n")
file.write("Welcome to Python file handling")

file.close()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Write mode(w)
#
#
# *   Creates a new file if it doesn't exist.
# *   If the file exists, all previous content is erased.

# %%
file=open("demo.txt","w")
file.write("Name:Ajay")
file.close()

# %% [markdown]
# #Create mode(x)

# %%
file=open("newfile.txt","x")
file.write("This is a newly created file")
file.close()

# %% [markdown]
# #Append mode(a)

# %%
file=open("demo.txt","a")
file.write("\nCollege: IIT Jodhpur")
file.write("\nSemester: II")
file.write("\nmarks: 30")
file.write("\naddress:kathmandu")
file.close()

print("Data appended succesfully")
# Out:
# Data appended succesfully

# %% [markdown]
# #Read mode (r)

# %%
file=open("demo.txt","r")
data=file.read()
print(data)
file.close()
# Out:
# Name:Ajay
# College: IIT Jodhpur
# Semester: II
# College: IIT Jodhpur
# Semester: II
# marks: 30
# College: IIT Jodhpur
# Semester: II
# marks: 30
# College: IIT Jodhpur
# Semester: II
# marks: 30
# address:kathmandu

# %%
with open("demo.txt","r") as file:
  print(file.read())
# Out:
# Name:Ajay
# College: IIT Jodhpur
# Semester: II
# College: IIT Jodhpur
# Semester: II
# marks: 30
# College: IIT Jodhpur
# Semester: II
# marks: 30
# College: IIT Jodhpur
# Semester: II
# marks: 30
# address:kathmandu

# %% [markdown]
# #r+ mode(read and write)

# %%
with open("sample.txt" ,"r+") as file:
  print("Before Writing:")
  print(file.read())

  file.write("\nWelcome to the second class of File Handling")
# Out:
# Before Writing:
# welcome to the first class of file handling

# %% [markdown]
# #w+ (write and read)

# %%
with open("sample.txt" ,"w+") as file:
  file.write("Python Handling")

  file.seek(0) #bring the position to the beginning of the file
  print(file.read())
# Out:
# Python Handling

# %% [markdown]
# # a+(append and read)

# %%
with open("sample.txt", "a+") as file:
  file.write("\nProgramming")
  file.seek(0)
  print(file.read())
# Out:
# Python Handling
# Programming
# Programming

# %%
#creating and writing a binary file
data=b"Hello,Python!" #b means bytes
with open("sample.bin","wb") as file:
  file.write(data)

print("Binary data file is created successfully")
# Out:
# Binary data file is created successfully

# %%
with open("sample.bin","rb") as file:
  content=file.read()
print(content)
# Out:
# b'Hello,Python!'

# %%
numbers=bytes([10,20,30,40,50])
with open("numbers.bin","wb") as file:
  file.write(numbers)

# %%
with open("numbers.bin","rb") as file:
  content=file.read()
print(content)
print(list(content))
# Out:
# b'\n\x14\x1e(2'
# [10, 20, 30, 40, 50]

# %%
#storing a python object using pickle
import pickle
student={
    "name":"ram",
    "age":25,
    "course":"Python"
}

with open("student.dat","wb") as file:
  pickle.dump(student,file)

print("Object Saved")
# Out:
# Object Saved

# %%
import pickle
with open("student.dat","rb") as file:
  student=pickle.load(file)

print(student)
# Out:
# {'name': 'ram', 'age': 25, 'course': 'Python'}

# %%
with open("images.jpeg","rb") as source:
  data=source.read()

with open("copy.jpg","wb") as destination:
  destination.write(data)

print("Image copied succesfully")
# Out:
# Image copied succesfully

# %% [markdown]
# #CSV files
#
# CSV (Comma-Separated Values) is one of the most common file formats for storing tabular data. It is widely used in Python because it is simple and can be opened in Excel, Google Sheets, and databases.

# %%
import csv

with open("Salary_Data.csv","r") as file:
  reader=csv.reader(file)

  next(reader)  #skip the first row
  for row in reader:
    print(row)
# Out:
# ['32', 'Male', "Bachelor's", 'Software Engineer', '5', '90000']
# ['28', 'Female', "Master's", 'Data Analyst', '3', '65000']
# ['45', 'Male', 'PhD', 'Senior Manager', '15', '150000']
# ['36', 'Female', "Bachelor's", 'Sales Associate', '7', '60000']
# ['52', 'Male', "Master's", 'Director', '20', '200000']
# ['29', 'Male', "Bachelor's", 'Marketing Analyst', '2', '55000']
# ['42', 'Female', "Master's", 'Product Manager', '12', '120000']
# ['31', 'Male', "Bachelor's", 'Sales Manager', '4', '80000']
# ['26', 'Female', "Bachelor's", 'Marketing Coordinator', '1', '45000']
# ['38', 'Male', 'PhD', 'Senior Scientist', '10', '110000']
# ['29', 'Male', "Master's", 'Software Developer', '3', '75000']
# ['48', 'Female', "Bachelor's", 'HR Manager', '18', '140000']
# ['35', 'Male', "Bachelor's", 'Financial Analyst', '6', '65000']
# ['40', 'Female', "Master's", 'Project Manager', '14', '130000']
# ['27', 'Male', "Bachelor's", 'Customer Service Rep', '2', '40000']
# ...

# %%
import csv
with open("Salary_Data.csv","r") as file:
  reader=csv.reader(file)

  next(reader)
  first_row=next(reader)
  print(first_row[0])
# Out:
# 32

# %%
import csv
data=[
    ["Name", "Age", "Course"],
    ["Ram", 20, "Python"],
    ["Sita", 22, "AI"],
    ["Hari", 21, "ML"]
]

with open("students.csv","w",newline="") as file:
  writer=csv.writer(file)
  writer.writerows(data)

# %%
with open("students.csv","a",newline="")as file:
  writer=csv.writer(file)
  writer.writerow(['Gita',23,'cybersecurity'])

# %%
import csv
with open("students.csv","r") as file:
  reader=csv.DictReader(file)

  for row in reader:
    print(row["Name"])
    print(row["Age"])
    print(row["Course"])
    print()
# Out:
# Ram
# 20
# Python
#
# Sita
# 22
# AI
#
# Hari
# 21
# ML
#
# Gita
# 23
# cybersecurity

# %%
import csv
with open("employee.csv","w",newline="")as file:
  fields=["Name","Age","Department"]
  writer=csv.DictWriter(file,fieldnames=fields)
  writer.writeheader()

  writer.writerow({
      "Name":"Shyam",
      "Age":27,
      "Department":"HR"
  })

# %%
{
    "name": "Ram",
    "age": [21,22,34],
    "course": "Python"
}

# %%
{
    "student": {
        "name": "Ram",
        "age": 22
    }
}

# %%
import json
with open("student.json","r") as file:
  data=json.load(file) #read the json file

print("Name:", data["name"])
print("Age:",data["age"])
# Out:
# Name: Ram
# Age: 22

# %%
#json.dump-writing into a json file
import json

student = {
    "name": "Ram",
    "age": 22,
    "course": "Python"
}

with open("student1.json", "w") as file:
    json.dump(student, file)

# %%
import json

json_string = '''
{
    "name":"Ram",
    "age":22,
    "course":"Python"
}
'''

student = json.loads(json_string)
print(student)
#print(student["name"])
# Out:
# {'name': 'Ram', 'age': 22, 'course': 'Python'}

# %% [markdown]
# #Error Handling

# %%
#syntax error
age=17
if age<18:
  print("I am elgiible")
# Out:
# I am elgiible

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3840/530406163.py in <cell line: 0>()
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
with open("student.dat","r") as file:
  pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3840/620282226.py in <cell line: 0>()
# ----> 1 with open("student.dat","r") as file:
#       2   pass
#
# FileNotFoundError: [Errno 2] No such file or directory: 'student.dat'

# %%
nums = iter([10, 20])
print(next(nums))
print(next(nums))
print(next(nums))
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_3840/4245769615.py in <cell line: 0>()
#       2 print(next(nums))
#       3 print(next(nums))
# ----> 4 print(next(nums))
#
# StopIteration:

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def numbers():
  yield 1
  yield 2

g=numbers()
g.close()

# %%
data=bytearray(b"Hello")
view=memoryview(data)

try:
  data.extend(b" world")

except BufferError as e:
  print(e)
# Out:
# Existing exports of data: object cannot be re-sized

# %%
from math import square
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_3840/909419403.py in <cell line: 0>()
# ----> 1 from math import square
#
# ImportError: cannot import name 'square' from 'math' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a = [0] * (10**20)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_3840/3377735032.py in <cell line: 0>()
# ----> 1 a = [0] * (10**20)
#
# OverflowError: cannot fit 'int' into an index-sized integer

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3840/179726827.py in <cell line: 0>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
print("Program Started")

num = 10 / 0

print("Program Ended")
# Out:
# Program Started
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3840/3950551939.py in <cell line: 0>()
#       1 print("Program Started")
#       2
# ----> 3 num = 10 / 0
#       4
#       5 print("Program Ended")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Syntax of Exception Handling

# %%
try:
    # Code that may cause an exception
except ExceptionType:
    # Code to handle the exception

# %%
try:
  number=int(input("Enter a number:"))
  print(100/number)

except ZeroDivisionError:
  print("You cannot divide a number by zero")
# Out:
# Enter a number:abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3840/2929929197.py in <cell line: 0>()
#       1 try:
# ----> 2   number=int(input("Enter a number:"))
#       3   print(100/number)
#       4
#       5 except ZeroDivisionError:
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
  number=int(input("Enter a number:"))
  print(100/number)

except ValueError:
  print("Please enter only valid numbers")

except ZeroDivisionError:
  print("You cannot divide a number by zero")
# Out:
# Enter a number:0
# You cannot divide a number by zero

# %%
balance=1000
try:
  amount=int(input("Enter withdrawal amount:"))
  if amount>balance:
    raise ValueError("Insufficient balance")

  balance-=amount
  print("Remanining balance:",balance)

except ValueError as e:
  print("Transaction failed",e)

finally:
  print("Thankyou for using our ATM")
# Out:
# Enter withdrawal amount:abchee
# Transaction failed invalid literal for int() with base 10: 'abchee'
# Thankyou for using our ATM

# %%
{
    "Model":"llama3",
    "temperature":
}

# %%
import json
file=None
try:
  print("opening configuration file")
  file=open("config.json","r")
  config=json.load(file)
  model=config["model"]
  temperature=config["temperature"]

except FileNotFoundError:
  print("Error: Configuration file not found.")

except json.JSONDecodeError:
  print("Error: Invalid JSON format.")

except KeyError as e:
    print(f"Missing configuration key: {e}")

else:
  print("\nConfiguration Loaded Successfully")
  print(f"Model        : {model}")
  print(f"Temperature  : {temperature}")

finally:
  if file:
    file.close()
    print("\nConfiguration file closed.")
# Out:
# opening configuration file
# Error: Configuration file not found.
